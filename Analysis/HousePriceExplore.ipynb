# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mapDirectory = "../Data/Map/"
hpDirectory = "/home/kdm11/Documents/Coding/python/twitter/DataChallenge/london2009-2014-house-prices/"

# %%
hp = pd.read_csv(hpDirectory + "Houseprice_2009_100km_London.csv")

# %%
hp[:]
# Out:
#            Price            Trdate  Postcode Property_Type Newbuild  \
# 0         83_500  2009-06-26 00:00   NN8 3NQ             S        N
# 1        150_000  2009-03-25 00:00   SM5 1EQ             T        N
# 2        227_000  2009-08-04 00:00   CR2 8PX             S        N
# 3        930_000  2009-10-12 00:00  SE24 9NU             T        N
# 4        183_750  2009-12-02 00:00  TN30 6RS             T        N
# 5        125_000  2009-05-08 00:00   CO3 9FE             F        N
# 6        350_000  2009-08-07 00:00   KT9 1AN             D        N
# 7        180_000  2009-09-14 00:00  DA17 5BH             T        N
# 8        220_000  2009-12-14 00:00   CB5 8QJ             S        N
# 9        535_000  2009-06-22 00:00   SM7 3AF             D        N
# 10       187_500  2009-08-07 00:00   OX3 9LB             S        N
# 11       201_000  2009-04-06 00:00  HP15 7RG             S        N
# 12       117_000  2009-12-18 00:00  OX10 9BP             F        N
# ...

# %%
hp.head()

# %% [markdown]
# Exploring the House Price Data
# ==============================
#
# Stuff.
